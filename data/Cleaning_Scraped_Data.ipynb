# %% [markdown]
# # Cleaning Scraped Data
# This notebook does cleaning of the scraped data

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import time
import json
import numpy as np

# %% [markdown]
# ### Reading the scraped json file

# %%
filename = 'indeed_'+time.strftime("%d-%m-%Y")+'.json'
df = pd.read_json(filename,orient='columns')

# %%
df['job_title'].value_counts()
# Out:
# technical writer     95
# data scientist       95
# software engineer    95
# Name: job_title, dtype: int64

# %% [markdown]
# ### Dropping the nulls and duplicate jobs

# %%
df = df.drop_duplicates()
df.reset_index(drop=True, inplace=True)

# %%
df['job_title'].value_counts()
# Out:
# data scientist       57
# software engineer    56
# technical writer     55
# Name: job_title, dtype: int64

# %% [markdown]
# ### Cleaning Salary column:
# Generated 4 columns:
# - salary_period : the time period of salary
# - salary_lower : the lower bound of salary
# - salary_upper : the upper bound of salary
# - salary average : the average bound of salary - calculated from lower and upper bound

# %%
df['job_salary'] = df['job_posting_salary']

# %%
df['job_posting_salary'] = df['job_posting_salary'].str.replace('\n', '')
df['job_posting_salary'] = df['job_posting_salary'].str.replace(',', '')
df['job_posting_salary'] = df['job_posting_salary'].str.replace('$', '')

# %%
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc     job_posting_salary  \
# 0  Job Class\nNON CLINICAL PROFESSIONAL\nFLSA\nEx...                   None
# 1  ContractWe are currently seeking a full stack ...                   None
# 2  $80,000 - $130,000 a yearFermata Energy is pio...  80000 - 130000 a year
# 3  ContractData Scientist:Databricks with Spark, ...                   None
# 4  $70 an hourAstral Techs is searching for a Dat...             70 an hour
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour

# %%
df['salary_period'] = 'None'
df['job_posting_salary'] = df['job_posting_salary'].fillna('None')
df.loc[(df['job_posting_salary'].str.contains("year")),'salary_period'] = 'year'
df.loc[(df['job_posting_salary'].str.contains("month")),'salary_period'] = 'month'
df.loc[(df['job_posting_salary'].str.contains("week")),'salary_period'] = 'week'
df.loc[(df['job_posting_salary'].str.contains("day")),'salary_period'] = 'day'
df.loc[(df['job_posting_salary'].str.contains("hour")),'salary_period'] = 'hour'

# %%
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc     job_posting_salary  \
# 0  Job Class\nNON CLINICAL PROFESSIONAL\nFLSA\nEx...                   None
# 1  ContractWe are currently seeking a full stack ...                   None
# 2  $80,000 - $130,000 a yearFermata Energy is pio...  80000 - 130000 a year
# 3  ContractData Scientist:Databricks with Spark, ...                   None
# 4  $70 an hourAstral Techs is searching for a Dat...             70 an hour
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period
# 0          None
# 1          None
# 2          year
# 3          None
# 4          hour

# %%
df['salary_period'].value_counts()
# Out:
# None    131
# year     27
# hour     10
# Name: salary_period, dtype: int64

# %%
df["job_posting_salary"] = df["job_posting_salary"].str.replace(" a year", '')
df["job_posting_salary"] = df["job_posting_salary"].str.replace(" a month", '')
df["job_posting_salary"] = df["job_posting_salary"].str.replace(" a week", '')
df["job_posting_salary"] = df["job_posting_salary"].str.replace(" a day", '')
df["job_posting_salary"] = df["job_posting_salary"].str.replace(" an hour", '')

# %%
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  Job Class\nNON CLINICAL PROFESSIONAL\nFLSA\nEx...               None
# 1  ContractWe are currently seeking a full stack ...               None
# 2  $80,000 - $130,000 a yearFermata Energy is pio...     80000 - 130000
# 3  ContractData Scientist:Databricks with Spark, ...               None
# 4  $70 an hourAstral Techs is searching for a Dat...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period
# 0          None
# 1          None
# 2          year
# 3          None
# 4          hour

# %%
df['salary_lower'] = df["job_posting_salary"].str.split(" - ", n=1, expand=True)[0]
df['salary_upper'] = df["job_posting_salary"].str.split(" - ", n=1, expand=True)[1]

# %%
df['salary_lower']=df['salary_lower'].replace('None',0)
df['salary_upper']=df['salary_upper'].fillna(0)
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  Job Class\nNON CLINICAL PROFESSIONAL\nFLSA\nEx...               None
# 1  ContractWe are currently seeking a full stack ...               None
# 2  $80,000 - $130,000 a yearFermata Energy is pio...     80000 - 130000
# 3  ContractData Scientist:Databricks with Spark, ...               None
# 4  $70 an hourAstral Techs is searching for a Dat...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period salary_lower salary_upper
# 0          None            0            0
# 1          None            0            0
# 2          year        80000       130000
# 3          None            0            0
# 4          hour           70            0

# %%
df['salary_lower'] = pd.to_numeric(df['salary_lower'])
df['salary_upper'] = pd.to_numeric(df['salary_upper'])
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  Job Class\nNON CLINICAL PROFESSIONAL\nFLSA\nEx...               None
# 1  ContractWe are currently seeking a full stack ...               None
# 2  $80,000 - $130,000 a yearFermata Energy is pio...     80000 - 130000
# 3  ContractData Scientist:Databricks with Spark, ...               None
# 4  $70 an hourAstral Techs is searching for a Dat...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period  salary_lower  salary_upper
# 0          None             0             0
# 1          None             0             0
# 2          year         80000        130000
# 3          None             0             0
# 4          hour            70             0

# %%
df.loc[df['salary_period'] == 'month','salary_lower'] = df['salary_lower']*12
df.loc[df['salary_period'] == 'month','salary_upper'] = df['salary_upper']*12
df.loc[df['salary_period'] == 'week','salary_lower'] = df['salary_lower']*52
df.loc[df['salary_period'] == 'week','salary_upper'] = df['salary_upper']*52
df.loc[df['salary_period'] == 'day','salary_lower'] = df['salary_lower']*260
df.loc[df['salary_period'] == 'day','salary_upper'] = df['salary_upper']*260
df.loc[df['salary_period'] == 'hour','salary_lower'] = df['salary_lower']*2080
df.loc[df['salary_period'] == 'hour','salary_upper'] = df['salary_upper']*2080

# %%
df['salary_average'] = np.where(df['salary_lower'] == 0,df['salary_upper'],(np.where(df['salary_upper'] == 0.0,df['salary_lower'],((df['salary_lower']+df['salary_upper'])/2))))

# %%
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  Job Class\nNON CLINICAL PROFESSIONAL\nFLSA\nEx...               None
# 1  ContractWe are currently seeking a full stack ...               None
# 2  $80,000 - $130,000 a yearFermata Energy is pio...     80000 - 130000
# 3  ContractData Scientist:Databricks with Spark, ...               None
# 4  $70 an hourAstral Techs is searching for a Dat...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period  salary_lower  salary_upper  salary_average
# 0          None             0             0             0.0
# 1          None             0             0             0.0
# 2          year         80000        130000        105000.0
# 3          None             0             0             0.0
# 4          hour        145600             0        145600.0

# %%
df_json = df.to_json(orient='records')
df_json
print(type(df_json))
with open('df_json.json','a') as file:
    json.dump(df_json,file)
# Out:
# <class 'str'>

# %% [markdown]
# ### Removing punctuation

# %%
def data_clean(df, column):
    cleaning_list = ['+','$','/',',','?','.',';','-','@','!','&','%','^','*',')',':','(','\n']
    for item in cleaning_list:
        df[column] = df[column].astype(str).str.replace(item, " ")

# %%
for column in df.columns[1:2]:
    data_clean(df, column)

# %%
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  Job Class NON CLINICAL PROFESSIONAL FLSA Exemp...               None
# 1  ContractWe are currently seeking a full stack ...               None
# 2   80 000    130 000 a yearFermata Energy is pio...     80000 - 130000
# 3  ContractData Scientist Databricks with Spark  ...               None
# 4   70 an hourAstral Techs is searching for a Dat...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period  salary_lower  salary_upper  salary_average
# 0          None             0             0             0.0
# 1          None             0             0             0.0
# 2          year         80000        130000        105000.0
# 3          None             0             0             0.0
# 4          hour        145600             0        145600.0

# %% [markdown]
# ### Cleaning Job description column

# %%
data = df[['job_posting_desc']]
data.head()
# Out:
#                                     job_posting_desc
# 0  Job Class NON CLINICAL PROFESSIONAL FLSA Exemp...
# 1  ContractWe are currently seeking a full stack ...
# 2   80 000    130 000 a yearFermata Energy is pio...
# 3  ContractData Scientist Databricks with Spark  ...
# 4   70 an hourAstral Techs is searching for a Dat...

# %% [markdown]
# ### Tokenizing the job_posting_desc column using NLTK library

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import string
from nltk.corpus import stopwords

# %%
# nltk.download()

# %%
# Removing \n from the String
for desc in df['job_posting_desc']:
    desc = desc.replace('\n','')
    desc = desc.replace('\\n','')
    desc = desc.translate(str.maketrans('', '', string.punctuation))
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  Job Class NON CLINICAL PROFESSIONAL FLSA Exemp...               None
# 1  ContractWe are currently seeking a full stack ...               None
# 2   80 000    130 000 a yearFermata Energy is pio...     80000 - 130000
# 3  ContractData Scientist Databricks with Spark  ...               None
# 4   70 an hourAstral Techs is searching for a Dat...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period  salary_lower  salary_upper  salary_average
# 0          None             0             0             0.0
# 1          None             0             0             0.0
# 2          year         80000        130000        105000.0
# 3          None             0             0             0.0
# 4          hour        145600             0        145600.0

# %% [markdown]
# ### Removing the stop words from job_posting_desc column

# %%
stopWords = set(stopwords.words('english'))
df['job_posting_desc'] = df['job_posting_desc'].str.lower().str.split()
df['job_posting_desc'] = df['job_posting_desc'].apply(lambda x : [item for item in x if item not in stopWords])
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  [job, class, non, clinical, professional, flsa...               None
# 1  [contractwe, currently, seeking, full, stack, ...               None
# 2  [80, 000, 130, 000, yearfermata, energy, pione...     80000 - 130000
# 3  [contractdata, scientist, databricks, spark, s...               None
# 4  [70, hourastral, techs, searching, data, scien...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period  salary_lower  salary_upper  salary_average
# 0          None             0             0             0.0
# 1          None             0             0             0.0
# 2          year         80000        130000        105000.0
# 3          None             0             0             0.0
# 4          hour        145600             0        145600.0

# %% [markdown]
# ### De-tokenizing the filtered job_posting_column

# %%
from nltk.tokenize.moses import MosesDetokenizer
detokenizer = MosesDetokenizer()
df['job_posting_desc'] = df['job_posting_desc'].apply(lambda x : [detokenizer.detokenize(x, return_str=True)])
df['job_posting_desc'] = df['job_posting_desc'].apply(lambda x : ''.join(x))
df['job_posting_desc'] = df['job_posting_desc'].str.replace('\d+', '')

# %%
df.head()
# Out:
#                     company  \
# 0  Greenville Health System
# 1              Aptonet, Inc
# 2            Fermata Energy
# 3              GISbiz, Inc.
# 4   Astral Technologies Inc
#
#                                     job_posting_desc job_posting_salary  \
# 0  job class non clinical professional flsa exemp...               None
# 1  contractwe currently seeking full stack java d...               None
# 2      yearfermata energy pioneering vehicle grid...     80000 - 130000
# 3  contractdata scientist databricks spark scala ...               None
# 4   hourastral techs searching data scientist res...                 70
#
#                                    job_posting_title  \
# 0                                     DATA SCIENTIST
# 1  Full Stack Java Developer w/Selenium and JUnit...
# 2        Machine Learning Developer / Data Scientist
# 3                      Data Scientist ( Data Bricks)
# 4                                     Data Scientist
#
#                                      job_posting_url          job_title  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...  software engineer
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...     data scientist
#
#      location  scrap_date scrap_website                 job_salary  \
# 0  Boston, MA  17-04-2019    indeed.com                       None
# 1  Boston, MA  17-04-2019    indeed.com                       None
# 2  Boston, MA  17-04-2019    indeed.com  $80,000 - $130,000 a year
# 3  Boston, MA  17-04-2019    indeed.com                       None
# 4  Boston, MA  17-04-2019    indeed.com                $70 an hour
#
#   salary_period  salary_lower  salary_upper  salary_average
# 0          None             0             0             0.0
# 1          None             0             0             0.0
# 2          year         80000        130000        105000.0
# 3          None             0             0             0.0
# 4          hour        145600             0        145600.0

# %% [markdown]
# ### Dumping the contents of cleaned dataframe into a json file

# %%
cleaned_filename = 'indeed_'+time.strftime("%d-%m-%Y")+'_cleaned.json'
df.to_json(cleaned_filename, orient='records')
